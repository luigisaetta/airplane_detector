# %% [markdown]
# ### Analyze Image distribution

# %%
import cv2

from os import path
from glob import glob

# %%
TRAIN_DIR = "/home/datascience/AirplaneDetector-8/train/images"

file_list = glob(path.join(TRAIN_DIR, "*.jpg"))

# %%
print(f"We have {len(file_list)} in the train dataset.")
# Out:
# We have 233 in the train dataset.

# %% [markdown]
# ### Tutte le immagini da Roboflow sono resized a 640x640

# %%
for f_name in file_list:
    img = cv2.imread(f_name)
    print(img.shape)
# Out:
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# (640, 640, 3)
# ...
